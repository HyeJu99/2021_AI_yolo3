# %% [markdown]
# #### 1) video to Img 실행

# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.5.4.60-cp39-cp39-win_amd64.whl (35.1 MB)
# ...

# %%
import cv2
import os

#폴더 만드는 함수
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

# 프레인 단위로 쪼갤 영성
filename = 'v28'

#영상의 위치
vidcap = cv2.VideoCapture(f'./video/{filename}.mp4')

#filename과 같은 이름의 폴더가 없으면 생성
createFolder(filename)

count = 0
num =0

while(vidcap.isOpened()):
    ret, image = vidcap.read()
    if ret is False:
        break;
    imageHeight, imageWidth = image.shape[:2]
    
    #5분의1로 resize
    resizeHeight = int(0.2*imageHeight)
    resizeWidth = int(0.2*imageWidth)
    if not ret:
        break
    
    # 캡쳐된 이미지를 저장하는 함수 
    if count%2==0:  #숫자를 조절(움직임이 많은 영상은 작게, 움직임이 적으면 크게)

        #하다보면 가로영상이 세로로 압축된 경우 resizeWidth와 resizeHeight를 바꾼다.
        image = cv2.resize(image,(resizeWidth,resizeHeight), interpolation=cv2.INTER_CUBIC)
        cv2.imwrite(f'./{filename}/{filename}_{num}.jpg',image)
 
        print(f'Saved {filename}_{num}.jpg')
        num+=1
    count += 1
 
vidcap.release()
cv2.destroyAllWindows()
# Out:
# Saved v28_0.jpg
# Saved v28_1.jpg
# Saved v28_2.jpg
# Saved v28_3.jpg
# Saved v28_4.jpg
# Saved v28_5.jpg
# Saved v28_6.jpg
# Saved v28_7.jpg
# Saved v28_8.jpg
# Saved v28_9.jpg
# Saved v28_10.jpg
# Saved v28_11.jpg
# Saved v28_12.jpg
# Saved v28_13.jpg
# Saved v28_14.jpg
# Saved v28_15.jpg
# Saved v28_16.jpg
# Saved v28_17.jpg
# Saved v28_18.jpg
# Saved v28_19.jpg
# Saved v28_20.jpg
# Saved v28_21.jpg
# Saved v28_22.jpg
# Saved v28_23.jpg
# Saved v28_24.jpg
# Saved v28_25.jpg
# Saved v28_26.jpg
# Saved v28_27.jpg
# Saved v28_28.jpg
# Saved v28_29.jpg
# Saved v28_30.jpg
# Saved v28_31.jpg
# Saved v28_32.jpg
# Saved v28_33.jpg
# Saved v28_34.jpg
# Saved v28_35.jpg
# Saved v28_36.jpg
# Saved v28_37.jpg
# Saved v28_38.jpg
# Saved v28_39.jpg
# Saved v28_40.jpg
# Saved v28_41.jpg
# Saved v28_42.jpg
# Saved v28_43.jpg
# Saved v28_44.jpg
# Saved v28_45.jpg
# Saved v28_46.jpg
# Saved v28_47.jpg
# Saved v28_48.jpg
# Saved v28_49.jpg
# Saved v28_50.jpg
# Saved v28_51.jpg
# Saved v28_52.jpg
# ...

# %%
#리사이즈 불포함
import cv2
import os

#폴더 만드는 함수
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

# 프레인 단위로 쪼갤 영성
filename = 'v17'

#영상의 위치
vidcap = cv2.VideoCapture(f'./video/{filename}.mp4')

#filename과 같은 이름의 폴더가 없으면 생성
createFolder(f'test/{filename}')

count = 0
num =0

while(vidcap.isOpened()):
    ret, image = vidcap.read()
    if ret is False:
        break;
    imageHeight, imageWidth = image.shape[:2]
    
    #5분의1로 resize
    #resizeHeight = int(0.2*imageHeight)
    #resizeWidth = int(0.2*imageWidth)
    if not ret:
        break
    
    # 캡쳐된 이미지를 저장하는 함수 
    if count%2==0:  #숫자를 조절(움직임이 많은 영상은 작게, 움직임이 적으면 크게)

        #하다보면 가로영상이 세로로 압축된 경우 resizeWidth와 resizeHeight를 바꾼다.
        image = cv2.resize(image,(imageWidth,imageHeight), interpolation=cv2.INTER_CUBIC)
        cv2.imwrite(f'./test/{filename}/{filename}_{num}.jpg',image)
 
        print(f'Saved {filename}_{num}.jpg')
        num+=1
    count += 1
 
vidcap.release()
cv2.destroyAllWindows()
# Out:
# Saved v17_0.jpg
# Saved v17_1.jpg
# Saved v17_2.jpg
# Saved v17_3.jpg
# Saved v17_4.jpg
# Saved v17_5.jpg
# Saved v17_6.jpg
# Saved v17_7.jpg
# Saved v17_8.jpg
# Saved v17_9.jpg
# Saved v17_10.jpg
# Saved v17_11.jpg
# Saved v17_12.jpg
# Saved v17_13.jpg
# Saved v17_14.jpg
# Saved v17_15.jpg
# Saved v17_16.jpg
# Saved v17_17.jpg
# Saved v17_18.jpg
# Saved v17_19.jpg
# Saved v17_20.jpg
# Saved v17_21.jpg
# Saved v17_22.jpg
# Saved v17_23.jpg
# Saved v17_24.jpg
# Saved v17_25.jpg
# Saved v17_26.jpg
# Saved v17_27.jpg
# Saved v17_28.jpg
# Saved v17_29.jpg
# Saved v17_30.jpg
# Saved v17_31.jpg
# Saved v17_32.jpg
# Saved v17_33.jpg
# Saved v17_34.jpg
# Saved v17_35.jpg
# Saved v17_36.jpg
# Saved v17_37.jpg
# Saved v17_38.jpg
# Saved v17_39.jpg
# Saved v17_40.jpg
# Saved v17_41.jpg
# Saved v17_42.jpg
# Saved v17_43.jpg
# Saved v17_44.jpg
# Saved v17_45.jpg
# Saved v17_46.jpg
# Saved v17_47.jpg
# Saved v17_48.jpg
# Saved v17_49.jpg
# Saved v17_50.jpg
# Saved v17_51.jpg
# Saved v17_52.jpg
# ...

# %%
# 파일 작성 예제
# writedata.py
fw = open("C:/doit/새파일.txt", 'w')
for i in range(1, 11):
    data = "%d번째 줄입니다.\n" % i
    fw.write(data)
fw.close()

# %%
# 바운딩 박스 크기 * 5
# 파일 읽어오고 오는대로 * 5 해서 문자열 + 로 저장 후, 내용 덮어씌우기
import os

video_name='v17'
index=0

while True:
    file_name=f'./test/{video_name}/{video_name}_{index}.txt'
    
    if os.path.isfile(file_name):
        f=open(file_name)
        for line in f.read().split('\n'):
            text = ''
            for word in line.split(' '):
                if word=='':
                    break
                if text == '':
                    text = word
                else: #if word > 0 and word < 1:
                    text = text + str(float(word)*5)
                print(text)
                
            fw = open(f'./test/{video_name}/new_{video_name}_{index}.txt', 'w')
            fw.write(text)
            fw.close()
            
            index+=1
    elif index > 361:
        break
    else:
        #print(index)
        index+=1
        continue
# Out:
# 1
# 12.63021
# 12.630211.985295
# 12.630211.9852950.5729150000000001
# 12.630211.9852950.57291500000000010.67647
# 1
# 12.578125
# 12.5781251.985295
# 12.5781251.9852950.364585
# 12.5781251.9852950.3645850.67647
# 1
# 12.5
# 12.51.985295
# 12.51.9852950.416665
# 12.51.9852950.4166650.617645
# 1
# 12.36979
# 12.369791.985295
# 12.369791.9852950.364585
# 12.369791.9852950.3645850.67647
# 1
# 12.16146
# 12.161461.9411749999999999
# 12.161461.94117499999999990.46875
# 12.161461.94117499999999990.468750.5882350000000001
# 1
# 11.927085
# 11.9270851.9264700000000001
# 11.9270851.92647000000000010.416665
# 11.9270851.92647000000000010.4166650.617645
# 1
# 11.69271
# 11.692711.8970600000000002
# 11.692711.89706000000000020.46875
# 11.692711.89706000000000020.468750.67647
# 1
# 11.40625
# 11.406251.867645
# 11.406251.8676450.416665
# 11.406251.8676450.4166650.67647
# 1
# 11.484375
# 11.4843751.838235
# 11.4843751.8382350.364585
# 11.4843751.8382350.3645850.617645
# 1
# 12.31771
# ...

# %% [markdown]
# #### 2) labelImg 실행

# %%
#!pip3 install labelImg
#!pyrcc5 -o resources.py resources.qrc
#cd 1122_labelImg-master
#!pyrcc5 -o libs/resources.py resources.qrc
# Out:
# 'pyrcc5'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# !python labelImg.py
# Out:
# Image:D:\HyeJu\capston\jupyter\1122_labelImg-master\v28\v28_0.jpg -> Annotation:D:/HyeJu/capston/jupyter/1122_labelImg-master/v28/v28_0.txt

# %% [markdown]
# #### 3) 종류별 count

# %%
import os

video_name='v28'
index=0

deer=0
beam=0
gcooter=0
others=0
while True:
    file_name=f'./{video_name}/{video_name}_{index}.txt'

    if os.path.isfile(file_name):
        f=open(file_name)
        for line in f.read().split('\n'):
            line=line.split(' ')
            if line[0]=='':
                break
            if int(line[0])==0:
                deer+=1
            elif int(line[0])==1:
                beam+=1
            elif int(line[0])==2:
                gcooter+=1
            elif int(line[0])==3:
                others+=1
        index+=1
    elif index > 361:
        break
    else:
        #print(index)
        index+=1
        continue

print(f'deer : {deer}개, beam : {beam}개, gcooter : {gcooter}개, others : {others}개')
print(f'총 사진: {index-1}개')
# Out:
# deer : 1개, beam : 0개, gcooter : 0개, others : 0개
# 총 사진: 361개
